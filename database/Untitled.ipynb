# %%
place = {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 12.9827288, 'lng': 77.59501089999999}, 'viewport': {'northeast': {'lat': 12.98412427989272, 'lng': 77.59629852989272}, 'southwest': {'lat': 12.98142462010728, 'lng': 77.59359887010729}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png', 'icon_background_color': '#FF9E67', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet', 'name': 'Cuz I have coffee', 'place_id': 'ChIJWezHicYXrjsRZfr6jYeI9yk', 'plus_code': {'compound_code': 'XHMW+32 Bengaluru, Karnataka', 'global_code': '7J4VXHMW+32'}, 'rating': 0, 'reference': 'ChIJWezHicYXrjsRZfr6jYeI9yk', 'scope': 'GOOGLE', 'types': ['restaurant', 'point_of_interest', 'food', 'establishment'], 'user_ratings_total': 0, 'vicinity': 'Coffee Board Head Office, Vasanth Nagar, Bengaluru'}

# %%
place
# Out:
# {'business_status': 'OPERATIONAL',
#  'geometry': {'location': {'lat': 12.9827288, 'lng': 77.59501089999999},
#   'viewport': {'northeast': {'lat': 12.98412427989272,
#     'lng': 77.59629852989272},
#    'southwest': {'lat': 12.98142462010728, 'lng': 77.59359887010729}}},
#  'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#  'icon_background_color': '#FF9E67',
#  'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#  'name': 'Cuz I have coffee',
#  'place_id': 'ChIJWezHicYXrjsRZfr6jYeI9yk',
#  'plus_code': {'compound_code': 'XHMW+32 Bengaluru, Karnataka',
#   'global_code': '7J4VXHMW+32'},
#  'rating': 0,
#  'reference': 'ChIJWezHicYXrjsRZfr6jYeI9yk',
#  'scope': 'GOOGLE',
#  'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#  'user_ratings_total': 0,
#  'vicinity': 'Coffee Board Head Office, Vasanth Nagar, Bengaluru'}

# %%
if place['business_status'] == 'OPERATIONAL':
    name = place['name']
    place_id = place['place_id']
    address = place['vicinity']
    types = place['types']

# %%
from bs4 import BeautifulSoup
import os
import csv
import json
import requests
from bs4 import BeautifulSoup
from urllib.parse import quote_plus

# %%
lat = 12.3375
long = 75.8069
test_api = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={lat}%2S{long}&radius=1500&type=point_of_interest&key=AIzaSyD5eTxgUd8qCGHFTHzSAMs8eSC3CvbSGbA"

response = requests.get(test_api)
image_metadata = response.json()['results']

# %%
image_metadata
# Out:
# []

# %%
test_api = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=12.3375%2C75.8069&type=locality&radius=15000&key=AIzaSyD5eTxgUd8qCGHFTHzSAMs8eSC3CvbSGbA"

response = requests.get(test_api)
image_metadata = response.json()['results']

# %%
alltypes = []
for each in image_metadata:
    for type in each['types']:
        if type not in alltypes:
            alltypes.append(type)

# %%
alltypes
# Out:
# ['locality', 'political']

# %%
image_metadata
# Out:
# [{'geometry': {'location': {'lat': 12.4244205, 'lng': 75.7381856},
#    'viewport': {'northeast': {'lat': 12.45399278113288,
#      'lng': 75.75651538375823},
#     'southwest': {'lat': 12.4088632808102, 'lng': 75.71322437988935}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/geocode-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': 'Madikeri',
#   'photos': [{'height': 3468,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101705757932466653687">Rabiya Sultana</a>'],
#     'photo_reference': 'AcJnMuFb3TXsSCnODWyInjyT7MwBDuHTQ0OuZg_np7qNCVAIDS2Wuva-dXaHlyg4IZ0ZaexMthD3aLcC9awvDbgVYQJKRN_YwWFEMdhGQVGJUCA6GmWfzaP2uuMbgIo7LmXbJ1QM0jeMmZQhxrHcKcXra9wbAALObFQkgFtEBh-VwOJB2yDu',
#     'width': 4624}],
#   'place_id': 'ChIJ_396YnUApTsRpsFRRupmiq8',
#   'reference': 'ChIJ_396YnUApTsRpsFRRupmiq8',
#   'scope': 'GOOGLE',
# ...

# %%
error_files = []
from bs4 import BeautifulSoup
def get_all_details(image_data):
    all_data = []
    for image_metadata in image_data:
        out_data = {}
        try:
            if image_metadata['business_status'] == 'OPERATIONAL':
                out_data['place_name'] = image_metadata['name']
                if 'photos' in image_metadata:
                    html_data = image_metadata['photos'][0]['html_attributions'][0]
                    out_data['map_reflink'] = BeautifulSoup(html_data, 'html.parser').a['href']
                    out_data['map_nametag'] = BeautifulSoup(html_data, 'html.parser').a.text
                    out_data['photo_reference'] = image_metadata['photos'][0]['photo_reference']
                else:
                    out_data['map_reflink'] = ''
                    out_data['photo_reference'] = ''
                    out_data['map_nametag'] = ''
                out_data['latitude_google'] = image_metadata['geometry']['location']['lat']
                out_data['longitude_google'] = image_metadata['geometry']['location']['lng']
                out_data['google_place_id'] = image_metadata['place_id']
                if 'rating' in image_metadata:
                    out_data['google_place_rating'] = image_metadata['rating']
                    out_data['google_user_rating'] = image_metadata['user_ratings_total']
                else:
                    out_data['google_place_rating'] = ''
                    out_data['google_user_rating'] = ''
                out_data['place_types'] = image_metadata['types']
                out_data['google_place_vicinity'] = image_metadata['vicinity']
        except Exception as e:
            error_files.append(f"error while reading {out_data['place_name']}")
        all_data.append(out_data)
    return all_data

# %%
import os
from datetime import date

all_types = ["restaurant","point_of_interest","food","lodging","hindu_temple","place_of_worship","museum","tourist_attraction"]
for type in all_types:
    for each in all_users:
        city = each[1]
        lat = str(each[2])
        lng = str(each[3])
        country = each[4]
        population = each[9]
        test_api = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?location="+lat+"%2C"+lng+"&type="+type+"&radius=15000&key=AIzaSyD5eTxgUd8qCGHFTHzSAMs8eSC3CvbSGbA"
        response = requests.get(test_api)
        image_metadata = response.json()['results']
        out_data = get_all_details(image_data)
        out_file_name = os.path.join("datafiles",f"{city}_{type}_{str(date.today())}_metadata.json")
        with open(out_file_name, 'w') as json_file:
            json.dump(out_data, json_file, indent=2)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/urllib3/connectionpool.py:403, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     402 try:
# --> 403     self._validate_conn(conn)
#     404 except (SocketTimeout, BaseSSLError) as e:
#     405     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/urllib3/connectionpool.py:1053, in HTTPSConnectionPool._validate_conn(self, conn)
#    1052 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1053     conn.connect()
#    1055 if not conn.is_verified:
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/urllib3/connection.py:419, in HTTPSConnection.connect(self)
#     417     context.load_default_certs()
# ...

# %%
for each in image_metadata:
    if each['business_status'] == 'OPERATIONAL':
        if 'photos' in each:
            ref_id = each['photos'][0]['photo_reference']
            name = each['name']
            t_api = f"https://maps.googleapis.com/maps/api/place/photo?maxwidth=400&photo_reference={ref_id}"
            response = requests.get(t_api)
            with open(f"{name}_image.png", 'wb') as f:
                f.write(response.content)

# %%
error_files
# Out:
# []

# %%
ref = "AcJnMuG2RcZXIvwYjXXMfwwh9MnCuC9-ewlFetvSPVAHT6FB0_PUdpj4Mh6FIyFokvB6b8lPxvcgCa8W5x3dNWr8_CBQcDFwLNI63p260wYtd5gSyggi8v0r7c4Chg3A0eT48Rlz_8mnkmxD6jGE0Xmt7_0Tu0-RPyR340jjtGdEbbA-SkWg"

t_api = f"https://maps.googleapis.com/maps/api/place/photo?maxwidth=400&photo_reference={ref}&key=AIzaSyD5eTxgUd8qCGHFTHzSAMs8eSC3CvbSGbA"

# %%
response = requests.get(t_api)
image_data = response

# %%
image_data
# Out:
# <Response [200]>

# %%
with open('map_image.png', 'wb') as f:
    f.write(response.content)

# %%
csv_file_path = "Places.csv"

# %%
# import sqlite3 

# with open(csv_file_path, 'r') as csv_file:
#     csv_reader = csv.reader(csv_file)
#     csv_file.seek(0)
#     next(csv_reader)  
#     for val in csv_reader:
#         city = val[0]
#         place = val[1].split(".")[1]
#         distance = val[2]
#         distancefromcitycenter = val[3]
#         description = val[4]
#         insert_load_world_data(city, place, distance, distancefromcitycenter, description)

# %%
def insert_load_place_data(city, place, distance, distancefromcitycenter, description):
    connection = sqlite3.connect(database_nm)
    cur = connection.cursor()
    cur.execute("INSERT INTO city_place (city, place, distance, distancefromcitycenter, description) VALUES (?, ?, ?, ?, ?)",
                    (city, place, distance, distancefromcitycenter, description))
    connection.commit()
    return "Record Inserted Successfully"

# %%
sql_statement = """CREATE TABLE city_place (
    city_id INTEGER PRIMARY KEY AUTOINCREMENT,
    city TEXT NOT NULL,
    place TEXT NOT NULL,
    distance FLOAT,
    distancefromcitycenter TEXT ,
    description TEXT
);"""

# %%
# Out:
# ('Delhi',
#  'Delhi',
#  28.61,
#  77.23,
#  'India',
#  'IN',
#  'IND',
#  'Delhi',
#  'admin',
#  32226000,
#  3)

# %%
database_nm = os.path.join("/Users/venkat/Desktop/TravelProjecr/travel_project/database", "travel_data_new.db")


connection = sqlite3.connect(database_nm)
cur = connection.cursor()
query = "SELECT * FROM indiancities"
all_users = cur.execute(query).fetchall()
print([user for user in all_users])
# Out:
# [('Delhi', 'Delhi', 28.61, 77.23, 'India', 'IN', 'IND', 'Delhi', 'admin', 32226000, 3), ('Mumbai', 'Mumbai', 19.0761, 72.8775, 'India', 'IN', 'IND', 'Mahārāshtra', 'admin', 24973000, 5), ('Kolkāta', 'Kolkata', 22.5675, 88.37, 'India', 'IN', 'IND', 'West Bengal', 'admin', 18502000, 15), ('Bangalore', 'Bangalore', 12.9789, 77.5917, 'India', 'IN', 'IND', 'Karnātaka', 'admin', 15386000, 23), ('Chennai', 'Chennai', 13.0825, 80.275, 'India', 'IN', 'IND', 'Tamil Nādu', 'admin', 12395000, 30), ('Hyderābād', 'Hyderabad', 17.385, 78.4867, 'India', 'IN', 'IND', 'Telangāna', 'admin', 10494000, 40), ('Pune', 'Pune', 18.5203, 73.8567, 'India', 'IN', 'IND', 'Mahārāshtra', '', 8231000, 60), ('Ahmedabad', 'Ahmedabad', 23.03, 72.58, 'India', 'IN', 'IND', 'Gujarāt', 'minor', 8009000, 62), ('Sūrat', 'Surat', 21.1702, 72.8311, 'India', 'IN', 'IND', 'Gujarāt', '', 6538000, 83), ('Prayagraj', 'Prayagraj', 25.4358, 81.8464, 'India', 'IN', 'IND', 'Uttar Pradesh', '', 5954391, 94), ('Lucknow', 'Lucknow', 26.8
# ...

# %%
import googlemaps
from pprint import pprint

# Replace 'YOUR_API_KEY' with your actual Google Places API key
gmaps = googlemaps.Client(key='AIzaSyD5eTxgUd8qCGHFTHzSAMs8eSC3CvbSGbA')

# Set the location to India
location = "India"

# Make a request to the Places API
places_result = gmaps.places(query=location)

# Extract and print place details
for place in places_result['results']:
    place_id = place['place_id']
    place_details = gmaps.place(place_id=place_id)
    pprint(place_details)
# Out:
# {'html_attributions': [],
#  'result': {'address_components': [{'long_name': 'India',
#                                     'short_name': 'IN',
#                                     'types': ['country', 'political']}],
#             'adr_address': '<span class="country-name">India</span>',
#             'formatted_address': 'India',
#             'geometry': {'location': {'lat': 20.593684, 'lng': 78.96288},
#                          'viewport': {'northeast': {'lat': 35.67454569461545,
#                                                     'lng': 97.39535874333608},
#                                       'southwest': {'lat': 6.46269991839241,
#                                                     'lng': 68.10969996381908}}},
#             'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/geocode-71.png',
#             'icon_background_color': '#7B9EB0',
#             'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
# ...
